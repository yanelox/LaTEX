# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
 
set_matplotlib_formats ('png')
# Out:
# /tmp/ipykernel_9599/4294946217.py:7: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats ('png')

# %%
m = [i + 1 for i in range (5)]
m = np.array (m)
m
# Out:
# array([1, 2, 3, 4, 5])

# %%
x0 = 52.8

# %%
x = list (map (float, input().split()))

# %%
x = np.array (x)
x
# Out:
# array([50.1, 50.8, 51.3, 51.6, 51.8])

# %%
sx = 0.1

# %%
lm = 578 / 10 ** 7

# %%
zm2 = 2 * np.sqrt (m * lm * (x0 - x))
zm2
# Out:
# array([0.0249848 , 0.03041052, 0.03225523, 0.03331306, 0.034     ])

# %%
szm = np.sqrt (lm * sx)
szm * 10 ** 4
# Out:
# 24.041630560342618

# %%
x1 = m
y1 = zm2 * 10 ** 4

# %%
plt.figure()

fig, ax1 = plt.subplots(figsize=(16, 16), dpi=100)

ax1.set_title ("2 * zm, мкм от m")

ax1.set_ylabel ("2 * zm, мкм") 
ax1.set_xlabel ("m")

# ax1.scatter (x1, y1, marker=".", s = 100)

plt.errorbar (x1, y1, yerr=szm * 10 ** 4, xerr=0, fmt='o-', ecolor='red', ls='none')

ax1.plot ([1, 5], [320, 320])

plt.savefig("./picturies/graph1.png", dpi=100)
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /mnt/126A613F6A6120A9/linux_work/LaTEX/labs/4.3.1/main.ipynb Cell 11' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/mnt/126A613F6A6120A9/linux_work/LaTEX/labs/4.3.1/main.ipynb#ch0000010?line=0'>1</a> plt.figure()
#       <a href='vscode-notebook-cell:/mnt/126A613F6A6120A9/linux_work/LaTEX/labs/4.3.1/main.ipynb#ch0000010?line=2'>3</a> fig, ax1 = plt.subplots(figsize=(16, 16), dpi=100)
#       <a href='vscode-notebook-cell:/mnt/126A613F6A6120A9/linux_work/LaTEX/labs/4.3.1/main.ipynb#ch0000010?line=4'>5</a> ax1.set_title ("2 * zm, мкм от m")
#
# NameError: name 'plt' is not defined

# %%
xm = list (map (float, input().split()))
xm = np.array (xm)
xm
# Out:
# array([1.46, 1.6 , 1.9 , 2.16, 2.34])

# %%
x2 = [i - 2 for i in range (5)]
y2 = xm
x2
# Out:
# [-2, -1, 0, 1, 2]

# %%
k2, s2 = np.polyfit (x2, y2, deg=1, cov=True)
print (k2, s2)
# Out:
# [0.232 1.892] [[ 2.08000000e-04 -7.88819965e-22]
#  [-7.88819965e-22  4.16000000e-04]]

# %%
plt.figure()

fig, ax1 = plt.subplots(figsize=(16, 16), dpi=100)

ax1.set_title ("Xm, мм от m")

ax1.set_ylabel ("Xm, мм") 
ax1.set_xlabel ("m")

# ax1.scatter (x1, y1, marker=".", s = 100)

plt.errorbar (x2, y2, yerr=0.05, xerr=0, fmt='o-', ecolor='red', ls='none')

ax1.plot (x2, np.poly1d (k2)(x2))

plt.savefig("./picturies/graph2.png", dpi=100)
plt.grid()
plt.show()
# Out:
# /tmp/ipykernel_9599/2302376692.py:12: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.errorbar (x2, y2, yerr=0.05, xerr=0, fmt='o-', ecolor='red', ls='none')

# %%
f2 = 12.5

# %%
D2 = f2 * lm / (k2[0] / 10)
D2 * 10 #в мм
# Out:
# 0.3114224137931037

# %%
D2_изм = 0.385

(D2 - D2_изм) / D2
# Out:
# -11.362629757785456

# %%
dx3 = 0.4 / 10 ** 2 #в cм

# %%
d3 = f2 * lm / dx3
d3  #в см
d3 * 10 #в мм
# Out:
# 1.8062500000000001

# %%
d3_изм = 2.52 - (0.56 + 0.28) / 2
d3_изм #в мм
# Out:
# 2.1

# %%
(d3_изм - d3) / d3
# Out:
# 0.1626297577854671

# %%
n3 = 2 * d3_изм / D2_изм
n3
# Out:
# 10.90909090909091

# %%
f1 = 9 # в см

# %%
b0 = (578 * 10 ** -9) * (9 / 100) / (d3 / 100)
b0 * 10 ** 3
# Out:
# 0.0288

# %%
D0 = (lm * f1) / d3
D0 # в см
D0 * 10 # в мм
# Out:
# 0.028800000000000003
