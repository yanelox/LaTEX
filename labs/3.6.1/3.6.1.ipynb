# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
 
set_matplotlib_formats ('png')
# Out:
# /tmp/ipykernel_7701/4294946217.py:7: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats ('png')

# %% [markdown]
# A

# %%
dva = list (map (float, input().split()))

# %%
ta = list(range (25, 201, 25))
ta = np.array (ta)

# %%
xa = 1 / ta
ya = np.array(dva) * 50 / 10

# %%
fig, ax1 = plt.subplots(figsize=(16, 16))

plt.rc('font', size = 20)

ax1.set_ylabel ("dv,КГц", size=20) 
ax1.set_xlabel ("t, (мкс)^(-1)", size=20)

ax1.scatter (xa, ya, marker="x", s = 100)
ax1.plot ([xa[0], xa[-1]], [ya[0], ya[-1]])
ax1.grid(True)

plt.savefig("pictures/graph1.png")
plt.show()

# %% [markdown]
# B

# %%
dvb = list (map (float, input().split()))
dvb = np.array (dvb)
dvb
# Out:
# array([ 555., 2500., 3333., 5000., 5000., 6666., 7500.])

# %%
vb = list (range (1, 8, 1))
vb = np.array (vb)
vb
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %%
yb = dvb / 1000
xb = vb

# %%
fig, ax1 = plt.subplots(figsize=(16, 16))

plt.rc('font', size = 20)

ax1.set_ylabel ("dv,КГц") 
ax1.set_xlabel ("f_повт, КГц")

ax1.scatter (xb, yb, marker="x", s = 100)
ax1.plot ([xb[0], xb[-1]], [yb[0], yb[-1]])
ax1.grid(True)

plt.savefig("pictures/graph2.png")
plt.show()

# %% [markdown]
# C

# %%
aside = list (map (float, input().split()))

# %%
dif = list (map (float, input().split()))

# %%
aside = np.array (aside)
dif = np.array (dif)

# %%
amain = aside / dif
amain
# Out:
# array([0.32193159, 0.32191781, 0.32202662, 0.32199819, 0.32198286,
#        0.3219697 ])

# %%
Amax = list (map (float, input().split()))

# %%
Amin = list (map (float, input().split()))

# %%
Amax = np.array (Amax)
Amin = np.array (Amin)

# %%
m = (Amax - Amin) / (Amax + Amin)

# %%
print (dif, Amax, Amin)
# Out:
# [0.0497 0.146  0.2329 0.3323 0.4317 0.4752] [1.1 1.3 1.5 1.7 1.9 2. ] [0.9 0.7 0.5 0.3 0.1 0. ]

# %%
xc = m
yc = dif

# %%
fig, ax1 = plt.subplots(figsize=(16, 16))

plt.rc('font', size = 20)

ax1.set_ylabel ("а_бок / а_осн") 
ax1.set_xlabel ("m")

ax1.scatter (xc, yc, marker="x", s = 100)
ax1.plot ([xc[0], xc[-1]], [yc[0], yc[-1]])
ax1.grid (True)

plt.savefig("pictures/graph3.png")
plt.show()

# %%
k_xy = (yc[-1] - yc[0]) / (xc[-1] - xc[0])
k_xy
# Out:
# 0.4727777777777778
